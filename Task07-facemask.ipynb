# %% [markdown]
# <a href="https://colab.research.google.com/github/maggy888/Task07-facemask/blob/main/Task07-facemask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hello Colab

# %% [markdown]
# # 新增區段

# %%
print('Hello World')
